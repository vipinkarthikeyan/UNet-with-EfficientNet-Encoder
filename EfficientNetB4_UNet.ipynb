# %%
# Import the necessary libraries

import tensorflow as tf
import tensorflow.keras as keras

# %%
# This loads the EfficientNetB4 model from the Keras library
# Input Shape is the shape of the image that is input to the first layer. For example, consider an image with shape (width, height , number of channels)
# 'include_top' is set to 'False' to load the model with out the classification or dense layers. Top layers are not required as this is a segmentation problem.
# 'weights' is set to imagenet, that is, it uses the weight it learnt while training on the imagenet dataset. You can set it to None or your custom_weights.
# IMAGE_WIDTH, IMAGE_HEIGHT and CHANNELS values provided for visualization. Please change to suit your dataset.

IMAGE_WIDTH = 512
IMAGE_HEIGHT = 512
CHANNELS = 3
model = tf.keras.applications.EfficientNetB4(input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, CHANNELS), 
                                             include_top=False, weights="imagenet")

# %%
#To see the list of layers and parameters
# For EfficientNetB4, you should see
'''Total params: 17,673,823
Trainable params: 17,548,616
Non-trainable params: 125,207'''

model.summary()
# Out:
# Model: "efficientnetb4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 512, 512, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 512, 512, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 513, 513, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 256, 256, 48) 1296        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 256, 256, 48) 192         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 256, 256, 48) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 256, 256, 48) 432         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 256, 256, 48) 192         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 256, 256, 48) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 48)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 48)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 12)     588         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 48)     624         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 256, 256, 48) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 256, 256, 24) 1152        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 256, 256, 24) 96          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 256, 256, 24) 216         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 256, 256, 24) 96          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 256, 256, 24) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 24)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 256, 256, 24) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 256, 256, 24) 576         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 256, 256, 24) 96          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 256, 256, 24) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 256, 256, 24) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 256, 256, 144 3456        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 256, 256, 144 576         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 256, 256, 144 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 257, 257, 144 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 128, 128, 144 1296        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 128, 128, 144 576         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 128, 128, 144 0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 144)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 128, 128, 144 0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 128, 128, 32) 4608        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 128, 128, 32) 128         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 128, 128, 192 6144        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 128, 128, 192 768         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 128, 128, 192 0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 128, 128, 192 1728        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 128, 128, 192 768         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 128, 128, 192 0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 192)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 128, 128, 192 0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 128, 128, 32) 6144        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 128, 128, 32) 128         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 128, 128, 32) 0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 128, 128, 32) 0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 128, 128, 192 6144        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 128, 128, 192 768         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 128, 128, 192 0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 128, 128, 192 1728        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 128, 128, 192 768         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 128, 128, 192 0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 192)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 128, 128, 192 0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 128, 128, 32) 6144        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 128, 128, 32) 128         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 128, 128, 32) 0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 128, 128, 32) 0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 128, 128, 192 6144        block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 128, 128, 192 768         block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 128, 128, 192 0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 128, 128, 192 1728        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 128, 128, 192 768         block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 128, 128, 192 0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 192)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 128, 128, 192 0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 128, 128, 32) 6144        block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 128, 128, 32) 128         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (Dropout)          (None, 128, 128, 32) 0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 128, 128, 32) 0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 128, 128, 192 6144        block2d_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 128, 128, 192 768         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 128, 128, 192 0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 131, 131, 192 0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 64, 64, 192)  4800        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 64, 64, 192)  768         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 64, 64, 192)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 192)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 64, 64, 192)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 64, 64, 56)   10752       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 64, 64, 56)   224         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 64, 64, 336)  18816       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 64, 64, 336)  1344        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 64, 64, 336)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 64, 64, 336)  8400        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 64, 64, 336)  1344        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 64, 64, 336)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 336)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 336)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 64, 64, 336)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 64, 64, 56)   18816       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 64, 64, 56)   224         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 64, 64, 56)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 64, 64, 56)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 64, 64, 336)  18816       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 64, 64, 336)  1344        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 64, 64, 336)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 64, 64, 336)  8400        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 64, 64, 336)  1344        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 64, 64, 336)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 336)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 336)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 64, 64, 336)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 64, 64, 56)   18816       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 64, 64, 56)   224         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 64, 64, 56)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 64, 64, 56)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 64, 64, 336)  18816       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 64, 64, 336)  1344        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 64, 64, 336)  0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 64, 64, 336)  8400        block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 64, 64, 336)  1344        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 64, 64, 336)  0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 336)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 336)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 64, 64, 336)  0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 64, 64, 56)   18816       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 64, 64, 56)   224         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (Dropout)          (None, 64, 64, 56)   0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 64, 64, 56)   0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 64, 64, 336)  18816       block3d_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 64, 64, 336)  1344        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 64, 64, 336)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 65, 65, 336)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 32, 32, 336)  3024        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 32, 32, 336)  1344        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 32, 32, 336)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 336)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 336)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 32, 32, 336)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 32, 32, 112)  37632       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 32, 32, 112)  448         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 32, 32, 672)  75264       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 32, 32, 672)  2688        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 32, 32, 672)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 32, 32, 672)  6048        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 32, 32, 672)  2688        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 32, 32, 672)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 672)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 32, 32, 672)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 32, 32, 112)  75264       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 32, 32, 112)  448         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 32, 32, 112)  0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 32, 32, 112)  0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 32, 32, 672)  75264       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 32, 32, 672)  2688        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 32, 32, 672)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 32, 32, 672)  6048        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 32, 32, 672)  2688        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 32, 32, 672)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 672)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 32, 32, 672)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 32, 32, 112)  75264       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 32, 32, 112)  448         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 32, 32, 112)  0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 32, 32, 112)  0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 32, 32, 672)  75264       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 32, 32, 672)  2688        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 32, 32, 672)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 32, 32, 672)  6048        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 32, 32, 672)  2688        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 32, 32, 672)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 672)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 32, 32, 672)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 32, 32, 112)  75264       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 32, 32, 112)  448         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (Dropout)          (None, 32, 32, 112)  0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 32, 32, 112)  0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_conv (Conv2D)    (None, 32, 32, 672)  75264       block4d_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_bn (BatchNormali (None, 32, 32, 672)  2688        block4e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4e_expand_activation (Acti (None, 32, 32, 672)  0           block4e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4e_dwconv (DepthwiseConv2D (None, 32, 32, 672)  6048        block4e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4e_bn (BatchNormalization) (None, 32, 32, 672)  2688        block4e_dwconv[0][0]
# __________________________________________________________________________________________________
# block4e_activation (Activation) (None, 32, 32, 672)  0           block4e_bn[0][0]
# __________________________________________________________________________________________________
# block4e_se_squeeze (GlobalAvera (None, 672)          0           block4e_activation[0][0]
# __________________________________________________________________________________________________
# block4e_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4e_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4e_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4e_se_excite (Multiply)    (None, 32, 32, 672)  0           block4e_activation[0][0]
#                                                                  block4e_se_expand[0][0]
# __________________________________________________________________________________________________
# block4e_project_conv (Conv2D)   (None, 32, 32, 112)  75264       block4e_se_excite[0][0]
# __________________________________________________________________________________________________
# block4e_project_bn (BatchNormal (None, 32, 32, 112)  448         block4e_project_conv[0][0]
# __________________________________________________________________________________________________
# block4e_drop (Dropout)          (None, 32, 32, 112)  0           block4e_project_bn[0][0]
# __________________________________________________________________________________________________
# block4e_add (Add)               (None, 32, 32, 112)  0           block4e_drop[0][0]
#                                                                  block4d_add[0][0]
# __________________________________________________________________________________________________
# block4f_expand_conv (Conv2D)    (None, 32, 32, 672)  75264       block4e_add[0][0]
# __________________________________________________________________________________________________
# block4f_expand_bn (BatchNormali (None, 32, 32, 672)  2688        block4f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4f_expand_activation (Acti (None, 32, 32, 672)  0           block4f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4f_dwconv (DepthwiseConv2D (None, 32, 32, 672)  6048        block4f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4f_bn (BatchNormalization) (None, 32, 32, 672)  2688        block4f_dwconv[0][0]
# __________________________________________________________________________________________________
# block4f_activation (Activation) (None, 32, 32, 672)  0           block4f_bn[0][0]
# __________________________________________________________________________________________________
# block4f_se_squeeze (GlobalAvera (None, 672)          0           block4f_activation[0][0]
# ...
# block6f_expand_bn (BatchNormali (None, 16, 16, 1632) 6528        block6f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6f_expand_activation (Acti (None, 16, 16, 1632) 0           block6f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6f_dwconv (DepthwiseConv2D (None, 16, 16, 1632) 40800       block6f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6f_bn (BatchNormalization) (None, 16, 16, 1632) 6528        block6f_dwconv[0][0]
# __________________________________________________________________________________________________
# block6f_activation (Activation) (None, 16, 16, 1632) 0           block6f_bn[0][0]
# __________________________________________________________________________________________________
# block6f_se_squeeze (GlobalAvera (None, 1632)         0           block6f_activation[0][0]
# __________________________________________________________________________________________________
# block6f_se_reshape (Reshape)    (None, 1, 1, 1632)   0           block6f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6f_se_reduce (Conv2D)      (None, 1, 1, 68)     111044      block6f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6f_se_expand (Conv2D)      (None, 1, 1, 1632)   112608      block6f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6f_se_excite (Multiply)    (None, 16, 16, 1632) 0           block6f_activation[0][0]
#                                                                  block6f_se_expand[0][0]
# __________________________________________________________________________________________________
# block6f_project_conv (Conv2D)   (None, 16, 16, 272)  443904      block6f_se_excite[0][0]
# __________________________________________________________________________________________________
# block6f_project_bn (BatchNormal (None, 16, 16, 272)  1088        block6f_project_conv[0][0]
# __________________________________________________________________________________________________
# block6f_drop (Dropout)          (None, 16, 16, 272)  0           block6f_project_bn[0][0]
# __________________________________________________________________________________________________
# block6f_add (Add)               (None, 16, 16, 272)  0           block6f_drop[0][0]
#                                                                  block6e_add[0][0]
# __________________________________________________________________________________________________
# block6g_expand_conv (Conv2D)    (None, 16, 16, 1632) 443904      block6f_add[0][0]
# __________________________________________________________________________________________________
# block6g_expand_bn (BatchNormali (None, 16, 16, 1632) 6528        block6g_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6g_expand_activation (Acti (None, 16, 16, 1632) 0           block6g_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6g_dwconv (DepthwiseConv2D (None, 16, 16, 1632) 40800       block6g_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6g_bn (BatchNormalization) (None, 16, 16, 1632) 6528        block6g_dwconv[0][0]
# __________________________________________________________________________________________________
# block6g_activation (Activation) (None, 16, 16, 1632) 0           block6g_bn[0][0]
# __________________________________________________________________________________________________
# block6g_se_squeeze (GlobalAvera (None, 1632)         0           block6g_activation[0][0]
# __________________________________________________________________________________________________
# block6g_se_reshape (Reshape)    (None, 1, 1, 1632)   0           block6g_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6g_se_reduce (Conv2D)      (None, 1, 1, 68)     111044      block6g_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6g_se_expand (Conv2D)      (None, 1, 1, 1632)   112608      block6g_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6g_se_excite (Multiply)    (None, 16, 16, 1632) 0           block6g_activation[0][0]
#                                                                  block6g_se_expand[0][0]
# __________________________________________________________________________________________________
# block6g_project_conv (Conv2D)   (None, 16, 16, 272)  443904      block6g_se_excite[0][0]
# __________________________________________________________________________________________________
# block6g_project_bn (BatchNormal (None, 16, 16, 272)  1088        block6g_project_conv[0][0]
# __________________________________________________________________________________________________
# block6g_drop (Dropout)          (None, 16, 16, 272)  0           block6g_project_bn[0][0]
# __________________________________________________________________________________________________
# block6g_add (Add)               (None, 16, 16, 272)  0           block6g_drop[0][0]
#                                                                  block6f_add[0][0]
# __________________________________________________________________________________________________
# block6h_expand_conv (Conv2D)    (None, 16, 16, 1632) 443904      block6g_add[0][0]
# __________________________________________________________________________________________________
# block6h_expand_bn (BatchNormali (None, 16, 16, 1632) 6528        block6h_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6h_expand_activation (Acti (None, 16, 16, 1632) 0           block6h_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6h_dwconv (DepthwiseConv2D (None, 16, 16, 1632) 40800       block6h_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6h_bn (BatchNormalization) (None, 16, 16, 1632) 6528        block6h_dwconv[0][0]
# __________________________________________________________________________________________________
# block6h_activation (Activation) (None, 16, 16, 1632) 0           block6h_bn[0][0]
# __________________________________________________________________________________________________
# block6h_se_squeeze (GlobalAvera (None, 1632)         0           block6h_activation[0][0]
# __________________________________________________________________________________________________
# block6h_se_reshape (Reshape)    (None, 1, 1, 1632)   0           block6h_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6h_se_reduce (Conv2D)      (None, 1, 1, 68)     111044      block6h_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6h_se_expand (Conv2D)      (None, 1, 1, 1632)   112608      block6h_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6h_se_excite (Multiply)    (None, 16, 16, 1632) 0           block6h_activation[0][0]
#                                                                  block6h_se_expand[0][0]
# __________________________________________________________________________________________________
# block6h_project_conv (Conv2D)   (None, 16, 16, 272)  443904      block6h_se_excite[0][0]
# __________________________________________________________________________________________________
# block6h_project_bn (BatchNormal (None, 16, 16, 272)  1088        block6h_project_conv[0][0]
# __________________________________________________________________________________________________
# block6h_drop (Dropout)          (None, 16, 16, 272)  0           block6h_project_bn[0][0]
# __________________________________________________________________________________________________
# block6h_add (Add)               (None, 16, 16, 272)  0           block6h_drop[0][0]
#                                                                  block6g_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 16, 16, 1632) 443904      block6h_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 16, 16, 1632) 6528        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 16, 16, 1632) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 16, 16, 1632) 14688       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 16, 16, 1632) 6528        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 16, 16, 1632) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1632)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1632)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 68)     111044      block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1632)   112608      block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 16, 16, 1632) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 16, 16, 448)  731136      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 16, 16, 448)  1792        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 16, 16, 2688) 1204224     block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 16, 16, 2688) 10752       block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 16, 16, 2688) 0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 16, 16, 2688) 24192       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 16, 16, 2688) 10752       block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 16, 16, 2688) 0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 2688)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 2688)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 112)    301168      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 2688)   303744      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 16, 16, 2688) 0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 16, 16, 448)  1204224     block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 16, 16, 448)  1792        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 16, 16, 448)  0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 16, 16, 448)  0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 16, 16, 1792) 802816      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 16, 16, 1792) 7168        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 16, 16, 1792) 0           top_bn[0][0]
# ==================================================================================================
# Total params: 17,673,823
# Trainable params: 17,548,616
# Non-trainable params: 125,207
# __________________________________________________________________________________________________

# %%
# Importing the layers to create the decoder and complete the network
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input 
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Concatenate
from tensorflow.keras import optimizers
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import MeanIoU, Recall, Precision
import tensorflow_addons as tfa

# %%
# Defining the Convolution Block
def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same", kernel_initializer="he_normal")(input)
    x = BatchNormalization()(x)
    #Used the Mish activation function as it performs better than ReLU (but is computionally expensive)
    x = tfa.activations.mish(x)
    #Comment the previous line and uncomment the next line if you limited compute resource
    #x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)
    x = tfa.activations.mish(x)
    #x = x*tf.math.tanh(tf.softplus(x)) #Mish activation in a mathematical form
    #x = Activation("relu")(x)

    return x

#Defining the Transpose Convolution Block
def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    #Use dropout only if the model is overfitting
    #x = Dropout(0.05)(x)
    x = conv_block(x, num_filters)
    return x

#Building the EfficientNetB4_UNet
def build_efficientNetB4_unet(input_shape):
    """ Input """
    inputs = Input(shape=input_shape, name='input_image')

    """ Pre-trained EfficientNetB4 Model """
    effNetB4 = tf.keras.applications.EfficientNetB4(input_tensor=inputs, include_top=False, 
                                                    weights="imagenet")
    # This Section will let you freeze and unfreeze layers. Here I have frozen all layer except
    # the last convolution block layers starting after layer 31
    for layer in effNetB4.layers[:-31]:
        layer.trainable = False
    for l in effNetB4.layers:
        print(l.name, l.trainable)

    """ Encoder """
    s1 = effNetB4.get_layer("input_image").output                   ## (512 x 512)
    s2 = effNetB4.get_layer("block1a_activation").output            ## (256 x 256)
    s3 = effNetB4.get_layer("block2a_activation").output            ## (128 x 128)
    s4 = effNetB4.get_layer("block3a_activation").output            ## (64 x 64)
    s5 = effNetB4.get_layer("block4a_activation").output            ## (32 x 32)

    """ Bridge """
    b1 = effNetB4.get_layer("block7a_activation").output  ## (16 x 16)

    """ Decoder """
    d1 = decoder_block(b1, s5, 512)                     ## (32 x 32)
    d2 = decoder_block(d1, s4, 256)                     ## (64 x 64)
    d3 = decoder_block(d2, s3, 128)                     ## (128 x 128)
    d4 = decoder_block(d3, s2, 64)                     ## (256 x 256)
    d5 = decoder_block(d4, s1, 32)                      ## (512 x 512)

    """ Output """
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d5)

    model = Model(inputs, outputs, name="EfficientNetB4_U-Net")
    return model

if __name__ == "__main__":
    input_shape = (IMAGE_WIDTH, IMAGE_HEIGHT, CHANNELS)
    model = build_efficientNetB4_unet(input_shape)
    #Shows the entire EfficientNetB4_UNet Model
    model.summary()
# Out:
# input_image False
# rescaling_4 False
# normalization_4 False
# stem_conv_pad False
# stem_conv False
# stem_bn False
# stem_activation False
# block1a_dwconv False
# block1a_bn False
# block1a_activation False
# block1a_se_squeeze False
# block1a_se_reshape False
# block1a_se_reduce False
# block1a_se_expand False
# block1a_se_excite False
# block1a_project_conv False
# block1a_project_bn False
# block1b_dwconv False
# block1b_bn False
# block1b_activation False
# block1b_se_squeeze False
# block1b_se_reshape False
# block1b_se_reduce False
# block1b_se_expand False
# block1b_se_excite False
# block1b_project_conv False
# block1b_project_bn False
# block1b_drop False
# block1b_add False
# block2a_expand_conv False
# block2a_expand_bn False
# block2a_expand_activation False
# block2a_dwconv_pad False
# block2a_dwconv False
# block2a_bn False
# block2a_activation False
# block2a_se_squeeze False
# block2a_se_reshape False
# block2a_se_reduce False
# block2a_se_expand False
# block2a_se_excite False
# block2a_project_conv False
# block2a_project_bn False
# block2b_expand_conv False
# block2b_expand_bn False
# block2b_expand_activation False
# block2b_dwconv False
# block2b_bn False
# block2b_activation False
# block2b_se_squeeze False
# block2b_se_reshape False
# block2b_se_reduce False
# block2b_se_expand False
# block2b_se_excite False
# block2b_project_conv False
# block2b_project_bn False
# block2b_drop False
# block2b_add False
# block2c_expand_conv False
# block2c_expand_bn False
# block2c_expand_activation False
# block2c_dwconv False
# block2c_bn False
# block2c_activation False
# block2c_se_squeeze False
# block2c_se_reshape False
# block2c_se_reduce False
# block2c_se_expand False
# block2c_se_excite False
# block2c_project_conv False
# block2c_project_bn False
# block2c_drop False
# block2c_add False
# block2d_expand_conv False
# block2d_expand_bn False
# block2d_expand_activation False
# block2d_dwconv False
# block2d_bn False
# block2d_activation False
# block2d_se_squeeze False
# block2d_se_reshape False
# block2d_se_reduce False
# block2d_se_expand False
# block2d_se_excite False
# block2d_project_conv False
# block2d_project_bn False
# block2d_drop False
# block2d_add False
# block3a_expand_conv False
# block3a_expand_bn False
# block3a_expand_activation False
# block3a_dwconv_pad False
# block3a_dwconv False
# block3a_bn False
# block3a_activation False
# block3a_se_squeeze False
# block3a_se_reshape False
# block3a_se_reduce False
# block3a_se_expand False
# block3a_se_excite False
# block3a_project_conv False
# block3a_project_bn False
# block3b_expand_conv False
# block3b_expand_bn False
# block3b_expand_activation False
# block3b_dwconv False
# block3b_bn False
# block3b_activation False
# block3b_se_squeeze False
# block3b_se_reshape False
# block3b_se_reduce False
# block3b_se_expand False
# block3b_se_excite False
# block3b_project_conv False
# block3b_project_bn False
# block3b_drop False
# block3b_add False
# block3c_expand_conv False
# block3c_expand_bn False
# block3c_expand_activation False
# block3c_dwconv False
# block3c_bn False
# block3c_activation False
# block3c_se_squeeze False
# block3c_se_reshape False
# block3c_se_reduce False
# block3c_se_expand False
# block3c_se_excite False
# block3c_project_conv False
# block3c_project_bn False
# block3c_drop False
# block3c_add False
# block3d_expand_conv False
# block3d_expand_bn False
# block3d_expand_activation False
# block3d_dwconv False
# block3d_bn False
# block3d_activation False
# block3d_se_squeeze False
# block3d_se_reshape False
# block3d_se_reduce False
# block3d_se_expand False
# block3d_se_excite False
# block3d_project_conv False
# block3d_project_bn False
# block3d_drop False
# block3d_add False
# block4a_expand_conv False
# block4a_expand_bn False
# block4a_expand_activation False
# block4a_dwconv_pad False
# block4a_dwconv False
# block4a_bn False
# block4a_activation False
# block4a_se_squeeze False
# block4a_se_reshape False
# block4a_se_reduce False
# block4a_se_expand False
# block4a_se_excite False
# block4a_project_conv False
# block4a_project_bn False
# block4b_expand_conv False
# block4b_expand_bn False
# block4b_expand_activation False
# block4b_dwconv False
# block4b_bn False
# block4b_activation False
# block4b_se_squeeze False
# block4b_se_reshape False
# block4b_se_reduce False
# block4b_se_expand False
# block4b_se_excite False
# block4b_project_conv False
# block4b_project_bn False
# block4b_drop False
# block4b_add False
# block4c_expand_conv False
# block4c_expand_bn False
# block4c_expand_activation False
# block4c_dwconv False
# block4c_bn False
# block4c_activation False
# block4c_se_squeeze False
# block4c_se_reshape False
# block4c_se_reduce False
# block4c_se_expand False
# block4c_se_excite False
# block4c_project_conv False
# block4c_project_bn False
# block4c_drop False
# block4c_add False
# block4d_expand_conv False
# block4d_expand_bn False
# block4d_expand_activation False
# block4d_dwconv False
# block4d_bn False
# block4d_activation False
# block4d_se_squeeze False
# block4d_se_reshape False
# block4d_se_reduce False
# block4d_se_expand False
# block4d_se_excite False
# block4d_project_conv False
# block4d_project_bn False
# block4d_drop False
# block4d_add False
# block4e_expand_conv False
# block4e_expand_bn False
# block4e_expand_activation False
# block4e_dwconv False
# block4e_bn False
# block4e_activation False
# block4e_se_squeeze False
# block4e_se_reshape False
# block4e_se_reduce False
# block4e_se_expand False
# block4e_se_excite False
# block4e_project_conv False
# block4e_project_bn False
# block4e_drop False
# block4e_add False
# block4f_expand_conv False
# block4f_expand_bn False
# block4f_expand_activation False
# block4f_dwconv False
# block4f_bn False
# block4f_activation False
# block4f_se_squeeze False
# block4f_se_reshape False
# block4f_se_reduce False
# block4f_se_expand False
# block4f_se_excite False
# block4f_project_conv False
# block4f_project_bn False
# block4f_drop False
# block4f_add False
# block5a_expand_conv False
# block5a_expand_bn False
# block5a_expand_activation False
# block5a_dwconv False
# block5a_bn False
# block5a_activation False
# block5a_se_squeeze False
# block5a_se_reshape False
# block5a_se_reduce False
# block5a_se_expand False
# block5a_se_excite False
# block5a_project_conv False
# block5a_project_bn False
# block5b_expand_conv False
# block5b_expand_bn False
# block5b_expand_activation False
# block5b_dwconv False
# block5b_bn False
# block5b_activation False
# block5b_se_squeeze False
# block5b_se_reshape False
# block5b_se_reduce False
# block5b_se_expand False
# block5b_se_excite False
# block5b_project_conv False
# block5b_project_bn False
# block5b_drop False
# block5b_add False
# block5c_expand_conv False
# block5c_expand_bn False
# block5c_expand_activation False
# block5c_dwconv False
# block5c_bn False
# block5c_activation False
# block5c_se_squeeze False
# block5c_se_reshape False
# block5c_se_reduce False
# block5c_se_expand False
# block5c_se_excite False
# block5c_project_conv False
# block5c_project_bn False
# block5c_drop False
# block5c_add False
# block5d_expand_conv False
# block5d_expand_bn False
# block5d_expand_activation False
# block5d_dwconv False
# block5d_bn False
# block5d_activation False
# block5d_se_squeeze False
# block5d_se_reshape False
# block5d_se_reduce False
# block5d_se_expand False
# block5d_se_excite False
# block5d_project_conv False
# block5d_project_bn False
# block5d_drop False
# block5d_add False
# block5e_expand_conv False
# block5e_expand_bn False
# block5e_expand_activation False
# block5e_dwconv False
# block5e_bn False
# block5e_activation False
# block5e_se_squeeze False
# block5e_se_reshape False
# block5e_se_reduce False
# block5e_se_expand False
# block5e_se_excite False
# block5e_project_conv False
# block5e_project_bn False
# block5e_drop False
# block5e_add False
# block5f_expand_conv False
# block5f_expand_bn False
# block5f_expand_activation False
# block5f_dwconv False
# block5f_bn False
# block5f_activation False
# block5f_se_squeeze False
# block5f_se_reshape False
# block5f_se_reduce False
# block5f_se_expand False
# block5f_se_excite False
# block5f_project_conv False
# block5f_project_bn False
# block5f_drop False
# block5f_add False
# block6a_expand_conv False
# block6a_expand_bn False
# block6a_expand_activation False
# block6a_dwconv_pad False
# block6a_dwconv False
# block6a_bn False
# block6a_activation False
# block6a_se_squeeze False
# block6a_se_reshape False
# block6a_se_reduce False
# block6a_se_expand False
# block6a_se_excite False
# block6a_project_conv False
# block6a_project_bn False
# block6b_expand_conv False
# block6b_expand_bn False
# block6b_expand_activation False
# block6b_dwconv False
# block6b_bn False
# block6b_activation False
# block6b_se_squeeze False
# block6b_se_reshape False
# block6b_se_reduce False
# block6b_se_expand False
# block6b_se_excite False
# block6b_project_conv False
# block6b_project_bn False
# block6b_drop False
# block6b_add False
# block6c_expand_conv False
# block6c_expand_bn False
# block6c_expand_activation False
# block6c_dwconv False
# block6c_bn False
# block6c_activation False
# block6c_se_squeeze False
# block6c_se_reshape False
# block6c_se_reduce False
# block6c_se_expand False
# block6c_se_excite False
# block6c_project_conv False
# block6c_project_bn False
# block6c_drop False
# block6c_add False
# block6d_expand_conv False
# block6d_expand_bn False
# block6d_expand_activation False
# block6d_dwconv False
# block6d_bn False
# block6d_activation False
# block6d_se_squeeze False
# block6d_se_reshape False
# block6d_se_reduce False
# block6d_se_expand False
# block6d_se_excite False
# block6d_project_conv False
# block6d_project_bn False
# block6d_drop False
# block6d_add False
# block6e_expand_conv False
# block6e_expand_bn False
# block6e_expand_activation False
# block6e_dwconv False
# block6e_bn False
# block6e_activation False
# block6e_se_squeeze False
# block6e_se_reshape False
# block6e_se_reduce False
# block6e_se_expand False
# block6e_se_excite False
# block6e_project_conv False
# block6e_project_bn False
# block6e_drop False
# block6e_add False
# block6f_expand_conv False
# block6f_expand_bn False
# block6f_expand_activation False
# block6f_dwconv False
# block6f_bn False
# block6f_activation False
# block6f_se_squeeze False
# block6f_se_reshape False
# block6f_se_reduce False
# block6f_se_expand False
# block6f_se_excite False
# block6f_project_conv False
# block6f_project_bn False
# block6f_drop False
# block6f_add False
# block6g_expand_conv False
# block6g_expand_bn False
# block6g_expand_activation False
# block6g_dwconv False
# block6g_bn False
# block6g_activation False
# block6g_se_squeeze False
# block6g_se_reshape False
# block6g_se_reduce False
# block6g_se_expand False
# block6g_se_excite False
# block6g_project_conv False
# block6g_project_bn False
# block6g_drop False
# block6g_add False
# block6h_expand_conv False
# block6h_expand_bn False
# block6h_expand_activation False
# block6h_dwconv False
# block6h_bn False
# block6h_activation False
# block6h_se_squeeze False
# block6h_se_reshape False
# block6h_se_reduce False
# block6h_se_expand False
# block6h_se_excite False
# block6h_project_conv False
# block6h_project_bn False
# block6h_drop False
# block6h_add False
# block7a_expand_conv True
# block7a_expand_bn True
# block7a_expand_activation True
# block7a_dwconv True
# block7a_bn True
# block7a_activation True
# block7a_se_squeeze True
# block7a_se_reshape True
# block7a_se_reduce True
# block7a_se_expand True
# block7a_se_excite True
# block7a_project_conv True
# block7a_project_bn True
# block7b_expand_conv True
# block7b_expand_bn True
# block7b_expand_activation True
# block7b_dwconv True
# block7b_bn True
# block7b_activation True
# block7b_se_squeeze True
# block7b_se_reshape True
# block7b_se_reduce True
# block7b_se_expand True
# block7b_se_excite True
# block7b_project_conv True
# block7b_project_bn True
# block7b_drop True
# block7b_add True
# top_conv True
# top_bn True
# top_activation True
# Model: "EfficientNetB4_U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# rescaling_4 (Rescaling)         (None, 512, 512, 3)  0           input_image[0][0]
# __________________________________________________________________________________________________
# normalization_4 (Normalization) (None, 512, 512, 3)  7           rescaling_4[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 513, 513, 3)  0           normalization_4[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 256, 256, 48) 1296        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 256, 256, 48) 192         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 256, 256, 48) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 256, 256, 48) 432         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 256, 256, 48) 192         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 256, 256, 48) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 48)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 48)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 12)     588         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 48)     624         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 256, 256, 48) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 256, 256, 24) 1152        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 256, 256, 24) 96          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 256, 256, 24) 216         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 256, 256, 24) 96          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 256, 256, 24) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 24)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 256, 256, 24) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 256, 256, 24) 576         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 256, 256, 24) 96          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 256, 256, 24) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 256, 256, 24) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 256, 256, 144 3456        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 256, 256, 144 576         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 256, 256, 144 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 257, 257, 144 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 128, 128, 144 1296        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 128, 128, 144 576         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 128, 128, 144 0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 144)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 128, 128, 144 0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 128, 128, 32) 4608        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 128, 128, 32) 128         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 128, 128, 192 6144        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 128, 128, 192 768         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 128, 128, 192 0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 128, 128, 192 1728        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 128, 128, 192 768         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 128, 128, 192 0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 192)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 128, 128, 192 0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 128, 128, 32) 6144        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 128, 128, 32) 128         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 128, 128, 32) 0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 128, 128, 32) 0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 128, 128, 192 6144        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 128, 128, 192 768         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 128, 128, 192 0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 128, 128, 192 1728        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 128, 128, 192 768         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 128, 128, 192 0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 192)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 128, 128, 192 0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 128, 128, 32) 6144        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 128, 128, 32) 128         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 128, 128, 32) 0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 128, 128, 32) 0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 128, 128, 192 6144        block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 128, 128, 192 768         block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 128, 128, 192 0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 128, 128, 192 1728        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 128, 128, 192 768         block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 128, 128, 192 0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 192)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 128, 128, 192 0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 128, 128, 32) 6144        block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 128, 128, 32) 128         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (Dropout)          (None, 128, 128, 32) 0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 128, 128, 32) 0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 128, 128, 192 6144        block2d_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 128, 128, 192 768         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 128, 128, 192 0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 131, 131, 192 0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 64, 64, 192)  4800        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 64, 64, 192)  768         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 64, 64, 192)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 192)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 64, 64, 192)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 64, 64, 56)   10752       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 64, 64, 56)   224         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 64, 64, 336)  18816       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 64, 64, 336)  1344        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 64, 64, 336)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 64, 64, 336)  8400        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 64, 64, 336)  1344        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 64, 64, 336)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 336)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 336)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 64, 64, 336)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 64, 64, 56)   18816       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 64, 64, 56)   224         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 64, 64, 56)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 64, 64, 56)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 64, 64, 336)  18816       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 64, 64, 336)  1344        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 64, 64, 336)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 64, 64, 336)  8400        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 64, 64, 336)  1344        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 64, 64, 336)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 336)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 336)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 64, 64, 336)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 64, 64, 56)   18816       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 64, 64, 56)   224         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 64, 64, 56)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 64, 64, 56)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 64, 64, 336)  18816       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 64, 64, 336)  1344        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 64, 64, 336)  0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 64, 64, 336)  8400        block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 64, 64, 336)  1344        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 64, 64, 336)  0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 336)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 336)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 64, 64, 336)  0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 64, 64, 56)   18816       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 64, 64, 56)   224         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (Dropout)          (None, 64, 64, 56)   0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 64, 64, 56)   0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 64, 64, 336)  18816       block3d_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 64, 64, 336)  1344        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 64, 64, 336)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 65, 65, 336)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 32, 32, 336)  3024        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 32, 32, 336)  1344        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 32, 32, 336)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 336)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 336)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 32, 32, 336)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 32, 32, 112)  37632       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 32, 32, 112)  448         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 32, 32, 672)  75264       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 32, 32, 672)  2688        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 32, 32, 672)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 32, 32, 672)  6048        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 32, 32, 672)  2688        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 32, 32, 672)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 672)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 32, 32, 672)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 32, 32, 112)  75264       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 32, 32, 112)  448         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 32, 32, 112)  0           block4b_project_bn[0][0]
# ...
# block7a_activation (Activation) (None, 16, 16, 1632) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 32, 32, 512)  3342848     block7a_activation[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 32, 32, 848)  0           conv2d_transpose_15[0][0]
#                                                                  block4a_activation[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 512)  3908096     concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 512)  2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_30 (TFOpLa (None, 32, 32, 512)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_30 (TFOpLambda (None, 32, 32, 512)  0           tf.convert_to_tensor_30[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_30 (TFOpLambda)    (None, 32, 32, 512)  0           tf.math.softplus_30[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_30 (TFOpLambda (None, 32, 32, 512)  0           tf.convert_to_tensor_30[0][0]
#                                                                  tf.math.tanh_30[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 512)  2359808     tf.math.multiply_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 32, 32, 512)  2048        conv2d_34[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_31 (TFOpLa (None, 32, 32, 512)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_31 (TFOpLambda (None, 32, 32, 512)  0           tf.convert_to_tensor_31[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_31 (TFOpLambda)    (None, 32, 32, 512)  0           tf.math.softplus_31[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_31 (TFOpLambda (None, 32, 32, 512)  0           tf.convert_to_tensor_31[0][0]
#                                                                  tf.math.tanh_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 64, 64, 256)  524544      tf.math.multiply_31[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 64, 64, 448)  0           conv2d_transpose_16[0][0]
#                                                                  block3a_activation[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 256)  1032448     concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 64, 64, 256)  1024        conv2d_35[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_32 (TFOpLa (None, 64, 64, 256)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_32 (TFOpLambda (None, 64, 64, 256)  0           tf.convert_to_tensor_32[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_32 (TFOpLambda)    (None, 64, 64, 256)  0           tf.math.softplus_32[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_32 (TFOpLambda (None, 64, 64, 256)  0           tf.convert_to_tensor_32[0][0]
#                                                                  tf.math.tanh_32[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 256)  590080      tf.math.multiply_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 64, 64, 256)  1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_33 (TFOpLa (None, 64, 64, 256)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_33 (TFOpLambda (None, 64, 64, 256)  0           tf.convert_to_tensor_33[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_33 (TFOpLambda)    (None, 64, 64, 256)  0           tf.math.softplus_33[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_33 (TFOpLambda (None, 64, 64, 256)  0           tf.convert_to_tensor_33[0][0]
#                                                                  tf.math.tanh_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 128, 128, 128 131200      tf.math.multiply_33[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 128, 128, 272 0           conv2d_transpose_17[0][0]
#                                                                  block2a_activation[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 128, 128, 128 313472      concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 128, 128, 128 512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_34 (TFOpLa (None, 128, 128, 128 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_34 (TFOpLambda (None, 128, 128, 128 0           tf.convert_to_tensor_34[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_34 (TFOpLambda)    (None, 128, 128, 128 0           tf.math.softplus_34[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_34 (TFOpLambda (None, 128, 128, 128 0           tf.convert_to_tensor_34[0][0]
#                                                                  tf.math.tanh_34[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 128, 128, 128 147584      tf.math.multiply_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 128, 128, 128 512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_35 (TFOpLa (None, 128, 128, 128 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_35 (TFOpLambda (None, 128, 128, 128 0           tf.convert_to_tensor_35[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_35 (TFOpLambda)    (None, 128, 128, 128 0           tf.math.softplus_35[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_35 (TFOpLambda (None, 128, 128, 128 0           tf.convert_to_tensor_35[0][0]
#                                                                  tf.math.tanh_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 256, 256, 64) 32832       tf.math.multiply_35[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 256, 256, 112 0           conv2d_transpose_18[0][0]
#                                                                  block1a_activation[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 256, 256, 64) 64576       concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 256, 256, 64) 256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_36 (TFOpLa (None, 256, 256, 64) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_36 (TFOpLambda (None, 256, 256, 64) 0           tf.convert_to_tensor_36[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_36 (TFOpLambda)    (None, 256, 256, 64) 0           tf.math.softplus_36[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_36 (TFOpLambda (None, 256, 256, 64) 0           tf.convert_to_tensor_36[0][0]
#                                                                  tf.math.tanh_36[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 256, 256, 64) 36928       tf.math.multiply_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 256, 256, 64) 256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_37 (TFOpLa (None, 256, 256, 64) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_37 (TFOpLambda (None, 256, 256, 64) 0           tf.convert_to_tensor_37[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_37 (TFOpLambda)    (None, 256, 256, 64) 0           tf.math.softplus_37[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_37 (TFOpLambda (None, 256, 256, 64) 0           tf.convert_to_tensor_37[0][0]
#                                                                  tf.math.tanh_37[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 512, 512, 32) 8224        tf.math.multiply_37[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 512, 512, 35) 0           conv2d_transpose_19[0][0]
#                                                                  input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 512, 512, 32) 10112       concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 512, 512, 32) 128         conv2d_41[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_38 (TFOpLa (None, 512, 512, 32) 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_38 (TFOpLambda (None, 512, 512, 32) 0           tf.convert_to_tensor_38[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_38 (TFOpLambda)    (None, 512, 512, 32) 0           tf.math.softplus_38[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_38 (TFOpLambda (None, 512, 512, 32) 0           tf.convert_to_tensor_38[0][0]
#                                                                  tf.math.tanh_38[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 512, 512, 32) 9248        tf.math.multiply_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 512, 512, 32) 128         conv2d_42[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_39 (TFOpLa (None, 512, 512, 32) 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_39 (TFOpLambda (None, 512, 512, 32) 0           tf.convert_to_tensor_39[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_39 (TFOpLambda)    (None, 512, 512, 32) 0           tf.math.softplus_39[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_39 (TFOpLambda (None, 512, 512, 32) 0           tf.convert_to_tensor_39[0][0]
#                                                                  tf.math.tanh_39[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 512, 512, 1)  33          tf.math.multiply_39[0][0]
# ==================================================================================================
# Total params: 25,366,380
# Trainable params: 12,981,121
# Non-trainable params: 12,385,259
# __________________________________________________________________________________________________

# %%
#Adding Model Checkpoints, Early Stopping based on Validation Loss and LR Reducer
model_path = "path/Model_Name.h5"
checkpointer = ModelCheckpoint(model_path,
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystopper = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 30,
                          verbose = 1,
                          restore_best_weights = True)

lr_reducer = ReduceLROnPlateau(monitor='val_loss',
                               factor=0.6,
                               patience=6,
                               verbose=1,
                               min_lr=0.0001
                               #min_delta=5e-5
                              )
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=6000,
    decay_rate=0.9)
optimizer = keras.optimizers.Adam(learning_rate=lr_schedule)

# %%
from tensorflow.keras import backend as K
# To calculate Intersection over Union between Predicted Mask and Ground Truth
def iou_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
  
    return iou

# %%
smooth = 1e-5
# F1 score or Dice Coefficient
def f1_score(y_true, y_pred, smooth = 1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Soft Dice Loss
def soft_dice_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
#Compiling the model with Adam Optimizer and Metrics related to segmentation
model.compile(optimizer=optimizer,
      loss=soft_dice_loss,
      metrics=[iou_coef, Recall(), Precision(), MeanIoU(num_classes=2), f1_score])

# %%
# Initiate Model Training
'''history = model.fit(train_images,
                    train_masks/255,
                    validation_split=0.10,
                    epochs=EPOCHS,
                    batch_size = BATCH_SIZE,
                    callbacks = [checkpointer, earlystopper, lr_reducer])'''
# Out:
# 'history = model.fit(train_images,\n                    train_masks/255,\n                    validation_split=0.10,\n                    epochs=EPOCHS,\n                    batch_size = BATCH_SIZE,\n                    callbacks = [checkpointer, earlystopper, lr_reducer])'
